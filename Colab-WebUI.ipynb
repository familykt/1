# %% [markdown]
# <a href="https://colab.research.google.com/github/familykt/1/blob/master/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Overwriting /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# /bin/bash: /usr/local/envs/GPTSoVITS/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ✨🍰✨ Everything looks OK!
# /bin/bash: /usr/local/envs/GPTSoVITS/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# bash: /usr/local/envs/GPTSoVITS/lib/libtinfo.so.6: no version information available (required by bash)
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
import os
# %pip install torchcodec
os.environ["LD_LIBRARY_PATH"] = "/usr/local/envs/GPTSoVITS/lib:" + os.environ.get("LD_LIBRARY_PATH", "")
os.environ["LD_PRELOAD"] = "/usr/local/envs/GPTSoVITS/lib/libstdc++.so.6:/usr/local/envs/GPTSoVITS/lib/libgcc_s.so.1"

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/envs/GPTSoVITS/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Error in sys.excepthook:
# Traceback (most recent call last):
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/tokenize.py", line 396, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/tokenize.py", line 365, in detect_encoding
#     first = read_or_stop()
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/tokenize.py", line 323, in read_or_stop
#     return readline()
# KeyboardInterrupt
#
# Original exception was:
# Traceback (most recent call last):
#   File "/content/GPT-SoVITS/webui.py", line 86, in <module>
#     from tools import my_utils
#   File "/content/GPT-SoVITS/tools/my_utils.py", line 7, in <module>
#     import gradio as gr
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/__init__.py", line 3, in <module>
#     import gradio._simple_templates
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/_simple_templates/__init__.py", line 1, in <module>
#     from .simpledropdown import SimpleDropdown
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/_simple_templates/simpledropdown.py", line 6, in <module>
#     from gradio.components.base import Component, FormComponent
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/components/__init__.py", line 40, in <module>
#     from gradio.components.native_plot import BarPlot, LinePlot, NativePlot, ScatterPlot
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/components/native_plot.py", line 16, in <module>
#     import pandas as pd
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/frame.py", line 153, in <module>
#     from pandas.core.generic import (
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/generic.py", line 155, in <module>
#     from pandas.core import (
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/indexing.py", line 80, in <module>
#     from pandas.core.indexes.api import (
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/indexes/api.py", line 28, in <module>
#     from pandas.core.indexes.datetimes import DatetimeIndex
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py", line 47, in <module>
#     from pandas.core.indexes.datetimelike import DatetimeTimedeltaMixin
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py", line 430, in <module>
#     class DatetimeTimedeltaMixin(DatetimeIndexOpsMixin, ABC):
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py", line 807, in DatetimeTimedeltaMixin
#     def delete(self, loc) -> Self:
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/util/_decorators.py", line 387, in decorator
#     [
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pandas/util/_decorators.py", line 390, in <listcomp>
#     else dedent(component.__doc__ or "")
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/textwrap.py", line 438, in dedent
#     text = _whitespace_only_re.sub('', text)
# KeyboardInterrupt
# ^C
